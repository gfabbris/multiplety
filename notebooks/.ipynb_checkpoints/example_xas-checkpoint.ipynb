# %%
import matplotlib.pyplot as plt
from multiplety.tools import calculate_xas,plot_xas,save_xas,load_xas

# %matplotlib nbagg

# %% [markdown]
# ## Calculation inputs

# %%
atomic_number = 28
atom_label = 'Ni2+'
gs_config = '2p6 3d8'
es_config = '2p5 3d9'

fdd = 80
fpd = 80
gpd = 80
coreso = 99
valso = 99

symmetry = 'C4h'
crystal_field = True
dq10 = 1.0
d1 = 0.0
d3 = 0.0

magnetic = False
mag_energy = 0.0

save_folder = 'example_xas_files/'

lifetime_width = 0.5
incident_resolution = 0.1

states_index = [1,2,3]

temperature = 300

# %% [markdown]
# ## Calculate XAS

# %%
xas = calculate_xas(atomic_number,atom_label,gs_config,es_config,
                  crystal_field,symmetry,magnetic,fdd,fpd,gpd,coreso,valso,
                  dq10,d1,d3,mag_energy,save_folder,states_index,
                  lifetime_width,incident_resolution,ein_min = 1E10,
                  ein_max=-1E10,ein_step=0.1,temperature = temperature,
                  verbose = True, skip_calc = False)
# Out:
# Starting RCN ... Done!
# Starting RCN2 ...  Done!
# Starting RCG ...  Done!
# Starting RACER ...
#
# Crystal field energies
# X400: 3.28633534503
# X420: -0.0
# X220: -0.0
# 10dq: 1.0
# dt: 0.0
# ds: 0.0
#
#
# Done!
# Generating calculations results ...
#
# States absolute energy (eV)
#
# 0+
#  -1.455
#  -1.441
#  -0.819
#  -0.766
#  -0.705
#  -0.464
#  0.697
#  0.829
#  0.880
#  0.904
#  5.263
#
# 1+
#  -2.428
#  -1.441
#  -1.402
#  -0.766
#  -0.680
#  0.413
#  0.850
#  0.880
#  1.119
#  1.886
#
# -1+
#  -2.428
#  -1.441
#  -1.402
#  -0.766
#  -0.680
#  0.413
#  0.850
#  0.880
#  1.119
#  1.886
#
# 2+
#  -2.428
#  -1.455
#  -1.402
#  -1.385
#  -0.705
#  -0.680
#  -0.464
#  0.413
#  0.829
#  0.850
#
#
# Ground state energy = -2.4280eV
# Symmetry  Energy(eV)
#
# -1+ -2.428041
# 1+ -2.428041
# 2+ -2.428041
# 0+ -1.454934
# 2+ -1.454934
# -1+ -1.441229
# 0+ -1.441229
# 1+ -1.441229
# -1+ -1.401512
# 1+ -1.401512
# 2+ -1.401512
# 2+ -1.385491
# 0+ -0.818546
# -1+ -0.766358
# ...

# %% [markdown]
# ## Save XAS calculation

# %%
save_xas(xas,atomic_number,atom_label,gs_config,es_config,
             crystal_field,symmetry,magnetic,fdd,fpd,gpd,coreso,valso,
             dq10,d1,d3,mag_energy,save_folder,states_index,
             lifetime_width,incident_resolution,temperature,fname = 'xas.dat')

# %% [markdown]
# ## Plot

# %%
plt.figure()

xas_plot = plot_xas(xas,plt.gca(),kind='linear')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Load a calculation

# %%
loaded_xas = load_xas(save_folder,'xas.dat')

# %% [markdown]
# ## Plot

# %%
plt.figure()

xas_plot = plot_xas(loaded_xas,plt.gca(),kind='linear')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
